# %%
import os
import re
import codecs
try:
    import cPickle as pickle
except ImportError:
    import pickle
import gc
import datetime,time

import numpy as np
import tensorflow as tf
import keras

from keras_contrib.layers import CRF
import keras.backend.tensorflow_backend as KTF

from tqdm import tqdm

from gensim.models import KeyedVectors
import multiprocessing
from gensim.models import Word2Vec
from gensim.models.word2vec import LineSentence

from conlleval import return_report

#进行配置，使用30%的GPU
configure = tf.ConfigProto()
configure.gpu_options.per_process_gpu_memory_fraction = 0.3
session = tf.Session(config=configure)

# 设置session
KTF.set_session(session )
# Out:
# Using TensorFlow backend.

# %%
base_dir = "./data_sets/"
train_file_path = os.path.join(base_dir, "train.txt")
dev_file_path = os.path.join(base_dir, "dev.txt")
test_file_path = os.path.join(base_dir, "test.txt")

embedding_path = os.path.join(base_dir, "word2vec.txt")

char_dico_path = os.path.join(base_dir, "maps.pkl")

model_path = './model/bilstm/bilstm_model.h5'
dev_result_path = "./temp/bilstm.txt"
test_result_path = "./result/bilstm/bilstm.txt"


tag_to_id ={
    'O': 0,   
    'B-t': 1,  'I-t': 2,  'E-t': 3,  'S-t': 4, 
    'B-j': 5,  'I-j': 6,  'E-j': 7,  'S-j': 8,
    'B-b': 9,  'I-b': 10, 'E-b': 11, 'S-b': 12,
    'B-z': 13, 'I-z': 14, 'E-z': 15, 'S-z': 16,
    'B-s': 17, 'I-s': 18, 'E-s': 19, 'S-s': 20}

max_len = 200

# %%
def zero_digits(s):
    """
    将数字都变为0
    :param s 输入句子
    """
    return re.sub('\d', '0', s)

def load_sentences(path, zeros=False):
    """
    载入句子
    """
    sentences = []
    sentence = []
    num = 0
    for line in codecs.open(path, 'r', 'utf8'):
        num += 1
        line = zero_digits(line.rstrip()) if zeros else line.rstrip()
        if not line:
            if len(sentence) > 0:
                if 'DOCSTART' not in sentence[0][0]:
                    sentences.append(sentence)
                sentence = []
        else:
            if line[0] == " ":
                line = "$" + line[1:]
                word = line.split()
            else:
                word= line.split()
            assert len(word) >= 2, print([word[0]])
            sentence.append(word)
    if len(sentence) > 0:
        if 'DOCSTART' not in sentence[0][0]:
            sentences.append(sentence)
    return sentences

def char_mapping(dico_path):
    with open(dico_path, 'rb') as f:
        char_to_id = pickle.load(f)
    id_to_char = {value: key for key, value in char_to_id.items()}
    return char_to_id, id_to_char
        
def prepare_dataset(sentences, char_to_id, tag_to_id, lower=False):
    def f(x):
        return x.lower() if lower else x
    data = []
    for s in sentences:
        string = [w[0] for w in s]
        chars = [char_to_id[f(w) if f(w) in char_to_id else '<UNK>'] for w in string]
        tags = [tag_to_id[w[-1]] for w in s]
        data.append([string, chars, tags])
    return data

def padding_data(data, max_len=200):
    """
    填充数据，不足的补0，超过部分截断
    """
    strings = []
    chars = []
    targets = []
    for line in tqdm(data):
        string, char, target = line
        if len(string) >= max_len:
            strings.append(string[0:max_len])
            chars.append(char[0:max_len])
            targets.append(target[0:max_len])
        else:
            padding = [0] * (max_len - len(string))
            strings.append(string + padding)
            chars.append(char + padding)
            targets.append(target + padding)
    return [strings, chars, targets]

def to_one_hot(targets, num_classes):
    """
    将标签变为one-hot表示
    """
    all_labels = []
    for target in targets:
        all_labels.append(tf.keras.utils.to_categorical(target, num_classes))
    return np.array(all_labels)

def get_train_dev_test(path, char_to_id, tag_to_id, num_classes, lower=False, max_len=200):
    """
    载入数据
    """
    sentences = load_sentences(path)
    data = prepare_dataset(sentences, char_to_id, tag_to_id, lower=lower)
    data = padding_data(data, max_len=max_len)
    X = np.array(data[1])
    y = to_one_hot(data[2], num_classes)
    return X, y
    

def load_word2vec(embedding_path, word_index, embed_dim=128): 
    """
    载入预训练好的word2vec(Google-News)
    """
    # 载入word2vec词向量
    word2vec_dict = KeyedVectors.load_word2vec_format(embedding_path, binary=False)
    
    embedding_index = dict()
    for word in word2vec_dict.wv.vocab:
        embedding_index[word] = word2vec_dict.word_vec(word)
    print('Load %s word vectors.' % len(embedding_index))
    
    all_embs = np.stack(list(embedding_index.values()))
    # emb_mean, emb_std = all_embs.mean(), all_embs.std()
    emb_mean = np.mean(all_embs, axis=0)
    vocab_size = len(word_index)
    # 初始化权重
    embedding_matrix = np.zeros((vocab_size+1, embed_dim))
    gc.collect()
    # 对权重矩阵进行赋值，未找到时用词向量平均值填充
    for word, i in word_index.items():
        if i < vocab_size + 1:
            embedding_vector = embedding_index.get(word)
            if embedding_vector is not None:
                embedding_matrix[i] = embedding_vector
            else:
                embedding_matrix[i] = emb_mean
    zero_vector = np.zeros((1, embed_dim))
    embedding_matrix[0] = zero_vector
    del embedding_index
    return embedding_matrix

def one_hot_to_label(one_hot, id_to_tag):
    """
    将one-hot变为标签
    """
    labels = []
    for tags in one_hot:
        temp = []
        for tag in tags:
            tag_id = tag.argmax()
            temp.append(id_to_tag[tag_id])
        labels.append(temp)
    return labels
            
def write_result(fpath, labels, result_path, char_to_id, tag_to_id, id_to_tag, lower=False, max_len=200):
    sentences = load_sentences(fpath)
    data = prepare_dataset(sentences, char_to_id, tag_to_id, lower=lower)
    temps = []
    for item in data:
        temp = []
        if len(item[0]) <= max_len:
            for i in range(len(item[0])):
                temp.append([item[0][i], id_to_tag[item[-1][i]]])
        temps.append(temp)
    all_data = []
    for i in range(len(temps)):
        temp = []
        if len(temps[i]) <= max_len:
            for j in range(len(temps[i])):
                m = temps[i][j]
                z = labels[i][j]
                m.append(z)
                temp.append(m)
            all_data.append(temp)
        else:
            labels[i] += ['O'] * (len(temps[i])-max_len)
            for j in range(len(temps[i])):
                m = temps[i][j]
                z = labels[i][j]
                m.append(z)
                temp.append(m)
            all_data.append(temp)
    with open(result_path, 'w', encoding="utf-8") as fw:
        for sentence in all_data:
            for item in sentence:
                fw.write(item[0] + ' ' + item[1] + ' ' + item[2] + '\n')
            fw.write('\n')
            
        
def evaluate(result_path):
    report = return_report(result_path)
    for item in report:
        print(item)

# %% [markdown]
# # 准备数据

# %%
char_to_id, id_to_char = char_mapping(char_dico_path)
X_train, y_train = get_train_dev_test(train_file_path, char_to_id, tag_to_id, len(tag_to_id))
X_dev, y_dev = get_train_dev_test(dev_file_path, char_to_id, tag_to_id, len(tag_to_id))
X_test, y_test = get_train_dev_test(test_file_path, char_to_id, tag_to_id, len(tag_to_id))
embedding_matrix = load_word2vec(embedding_path, char_to_id)
id_to_tag = {value: key for key, value in tag_to_id.items()}
# Out:
# 100%|██████████| 3543/3543 [00:00<00:00, 86983.41it/s]
# 100%|██████████| 1517/1517 [00:00<00:00, 104461.65it/s]
# 100%|██████████| 2123/2123 [00:00<00:00, 20660.83it/s]
# Load 2122 word vectors.
# /home/pipigou/anaconda3/envs/bert/lib/python3.6/site-packages/ipykernel_launcher.py:102: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).

# %%
print("训练集信息：句子：{}, 标签：{}".format(X_train.shape, y_train.shape))
print("验证集信息：句子：{}, 标签：{}".format(X_dev.shape, y_dev.shape))
print("测试集信息：句子：{}, 标签：{}".format(X_test.shape, y_test.shape))
print("Embedding信息：{}".format(embedding_matrix.shape))
# Out:
# 训练集信息：句子：(3543, 200), 标签：(3543, 200, 21)
# 验证集信息：句子：(1517, 200), 标签：(1517, 200, 21)
# 测试集信息：句子：(2123, 200), 标签：(2123, 200, 21)
# Embedding信息：(2124, 128)

# %% [markdown]
# # 超参数配置

# %%
class Config:
    max_len = 200
    lstm_dim = 100
    vocab_size = len(char_to_id)
    class_nums = len(tag_to_id)
    embedding_dim = 128
    dropout_rate = 0.5
    epochs = 120
    batch_size = 128
    
config = Config()

# %% [markdown]
# # 搭建模型

# %%
# Input Layer
char_input = keras.layers.Input(shape=(config.max_len,), name="char_input_layer")
# Embedding Layer
embedding_layer = keras.layers.Embedding(config.vocab_size+1,
                                         config.embedding_dim,
                                         weights=[embedding_matrix],
                                         input_length=config.max_len,
                                         mask_zero=True,
                                         trainable=False)(char_input)
# BiLSTM Layer
bilstm = keras.layers.Bidirectional(keras.layers.LSTM(config.lstm_dim, unroll=False, return_sequences=True))(embedding_layer)
# Dropout Layer
dropout_layer = keras.layers.Dropout(config.dropout_rate)(bilstm)
# CRF Layer
crf = CRF(config.class_nums, sparse_target=False)
crf_layer = crf(dropout_layer)

model = keras.models.Model(inputs=char_input, outputs=crf_layer)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# char_input_layer (InputLayer (None, 200)               0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 200, 128)          271872
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 200, 200)          183200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 200, 200)          0
# _________________________________________________________________
# crf_1 (CRF)                  (None, 200, 21)           4704
# =================================================================
# Total params: 459,776
# Trainable params: 187,904
# Non-trainable params: 271,872
# _________________________________________________________________

# %% [markdown]
# # 模型训练

# %%
from keras_contrib.losses import crf_loss
from keras_contrib.metrics import crf_accuracy

adadelta = keras.optimizers.Adadelta(lr=1.0, rho=0.95, epsilon=1e-06)
# model.compile(loss=crf.loss_function, optimizer=adadelta, metrics=[crf.accuracy])
model.compile(loss=crf_loss, optimizer=adadelta, metrics=[crf_accuracy])

best_fscore = 0
for i in range(config.epochs):
    print('Epoch '+str(i+1)+"/"+str(config.epochs))
    model.fit(X_train, y_train, nb_epoch=1, batch_size=config.batch_size)
    y_pred = model.predict(X_dev, batch_size=config.batch_size)
    labels = one_hot_to_label(y_pred, id_to_tag)
    write_result(dev_file_path, labels, dev_result_path, char_to_id, tag_to_id, id_to_tag)
    report, fscore = return_report(dev_result_path)
    for item in report:
        print(item)
    if fscore > best_fscore:
        model.save(model_path)
        best_fscore = fscore
# Out:
# Epoch 1/120
# /home/pipigou/anaconda3/envs/bert/lib/python3.6/site-packages/ipykernel_launcher.py:11: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   # This is added back by InteractiveShellApp.init_path()
# Epoch 1/1
# 3543/3543 [==============================] - 30s 9ms/step - loss: 28.0245 - crf_accuracy: 0.6621
# processed 59449 tokens with 6198 phrases; found: 1604 phrases; correct: 422.
#
# accuracy:  72.65%; precision:  26.31%; recall:   6.81%; FB1:  10.82
#
#                 b: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#
#                 j: precision:  18.74%; recall:   3.91%; FB1:   6.47  459
#
#                 s: precision:  14.47%; recall:   5.58%; FB1:   8.06  767
#
#                 t: precision:  60.65%; recall:  15.19%; FB1:  24.30  371
#
#                 z: precision:   0.00%; recall:   0.00%; FB1:   0.00  7
#
# Epoch 2/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 27.5183 - crf_accuracy: 0.7550
# processed 59449 tokens with 6198 phrases; found: 3888 phrases; correct: 1941.
#
# accuracy:  79.43%; precision:  49.92%; recall:  31.32%; FB1:  38.49
#
#                 b: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#
#                 j: precision:  46.72%; recall:  26.23%; FB1:  33.60  1235
#
#                 s: precision:  37.10%; recall:  27.70%; FB1:  31.72  1485
#
#                 t: precision:  73.42%; recall:  54.83%; FB1:  62.78  1106
#
#                 z: precision:   1.61%; recall:   0.30%; FB1:   0.51  62
#
# Epoch 3/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 27.3390 - crf_accuracy: 0.7993
# processed 59449 tokens with 6198 phrases; found: 4406 phrases; correct: 2691.
#
# accuracy:  82.82%; precision:  61.08%; recall:  43.42%; FB1:  50.75
#
#                 b: precision:   9.68%; recall:   1.53%; FB1:   2.64  31
#
#                 j: precision:  58.35%; recall:  36.36%; FB1:  44.81  1371
#
#                 s: precision:  53.45%; recall:  42.43%; FB1:  47.31  1579
#
#                 t: precision:  79.43%; recall:  69.89%; FB1:  74.35  1303
#
#                 z: precision:   7.38%; recall:   2.71%; FB1:   3.96  122
#
# Epoch 4/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 27.2317 - crf_accuracy: 0.8288
# processed 59449 tokens with 6198 phrases; found: 4889 phrases; correct: 3315.
#
# accuracy:  85.69%; precision:  67.81%; recall:  53.48%; FB1:  59.80
#
#                 b: precision:  25.00%; recall:  12.24%; FB1:  16.44  96
#
#                 j: precision:  69.46%; recall:  55.32%; FB1:  61.59  1752
#
#                 s: precision:  59.70%; recall:  47.96%; FB1:  53.19  1598
#
#                 t: precision:  83.07%; recall:  74.88%; FB1:  78.76  1335
#
#                 z: precision:  10.19%; recall:   3.31%; FB1:   5.00  108
#
# Epoch 5/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 27.1598 - crf_accuracy: 0.8484
# processed 59449 tokens with 6198 phrases; found: 4613 phrases; correct: 3397.
#
# accuracy:  86.17%; precision:  73.64%; recall:  54.81%; FB1:  62.84
#
#                 b: precision:  28.77%; recall:  10.71%; FB1:  15.61  73
#
#                 j: precision:  75.70%; recall:  57.50%; FB1:  65.36  1671
#
#                 s: precision:  64.78%; recall:  52.99%; FB1:  58.30  1627
#
#                 t: precision:  91.07%; recall:  70.90%; FB1:  79.73  1153
#
#                 z: precision:   7.87%; recall:   2.11%; FB1:   3.33  89
#
# Epoch 6/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 27.1064 - crf_accuracy: 0.8621
# processed 59449 tokens with 6198 phrases; found: 5108 phrases; correct: 3829.
#
# accuracy:  87.80%; precision:  74.96%; recall:  61.78%; FB1:  67.73
#
#                 b: precision:  36.27%; recall:  18.88%; FB1:  24.83  102
#
#                 j: precision:  78.48%; recall:  69.45%; FB1:  73.69  1947
#
#                 s: precision:  67.34%; recall:  58.87%; FB1:  62.82  1739
#
#                 t: precision:  90.53%; recall:  72.92%; FB1:  80.78  1193
#
#                 z: precision:  10.24%; recall:   3.92%; FB1:   5.66  127
#
# Epoch 7/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 27.0685 - crf_accuracy: 0.8734
# processed 59449 tokens with 6198 phrases; found: 5274 phrases; correct: 4114.
#
# accuracy:  89.04%; precision:  78.01%; recall:  66.38%; FB1:  71.72
#
#                 b: precision:  47.57%; recall:  25.00%; FB1:  32.78  103
#
#                 j: precision:  82.75%; recall:  76.95%; FB1:  79.75  2046
#
#                 s: precision:  70.83%; recall:  60.78%; FB1:  65.42  1707
#
#                 t: precision:  89.87%; recall:  77.25%; FB1:  83.08  1273
#
#                 z: precision:  13.10%; recall:   5.72%; FB1:   7.97  145
#
# Epoch 8/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 27.0380 - crf_accuracy: 0.8817
# processed 59449 tokens with 6198 phrases; found: 5570 phrases; correct: 4379.
#
# accuracy:  90.13%; precision:  78.62%; recall:  70.65%; FB1:  74.42
#
#                 b: precision:  51.01%; recall:  38.78%; FB1:  44.06  149
#
#                 j: precision:  83.29%; recall:  82.45%; FB1:  82.87  2178
#
#                 s: precision:  72.38%; recall:  62.44%; FB1:  67.04  1716
#
#                 t: precision:  89.52%; recall:  81.36%; FB1:  85.25  1346
#
#                 z: precision:  23.20%; recall:  12.65%; FB1:  16.37  181
#
# Epoch 9/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 27.0127 - crf_accuracy: 0.8882
# processed 59449 tokens with 6198 phrases; found: 5600 phrases; correct: 4469.
#
# accuracy:  90.59%; precision:  79.80%; recall:  72.10%; FB1:  75.76
#
#                 b: precision:  60.45%; recall:  41.33%; FB1:  49.09  134
#
#                 j: precision:  84.87%; recall:  82.59%; FB1:  83.71  2141
#
#                 s: precision:  73.33%; recall:  65.81%; FB1:  69.37  1785
#
#                 t: precision:  89.51%; recall:  82.98%; FB1:  86.12  1373
#
#                 z: precision:  19.76%; recall:   9.94%; FB1:  13.23  167
#
# Epoch 10/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.9928 - crf_accuracy: 0.8939
# processed 59449 tokens with 6198 phrases; found: 5857 phrases; correct: 4623.
#
# accuracy:  90.92%; precision:  78.93%; recall:  74.59%; FB1:  76.70
#
#                 b: precision:  65.93%; recall:  45.41%; FB1:  53.78  135
#
#                 j: precision:  84.36%; recall:  85.09%; FB1:  84.73  2219
#
#                 s: precision:  70.69%; recall:  67.67%; FB1:  69.15  1904
#
#                 t: precision:  88.82%; recall:  85.82%; FB1:  87.29  1431
#
#                 z: precision:  26.79%; recall:  13.55%; FB1:  18.00  168
#
# Epoch 11/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.9762 - crf_accuracy: 0.8977
# processed 59449 tokens with 6198 phrases; found: 5798 phrases; correct: 4635.
#
# accuracy:  91.29%; precision:  79.94%; recall:  74.78%; FB1:  77.28
#
#                 b: precision:  62.99%; recall:  49.49%; FB1:  55.43  154
#
#                 j: precision:  85.48%; recall:  85.64%; FB1:  85.56  2204
#
#                 s: precision:  71.83%; recall:  67.42%; FB1:  69.55  1867
#
#                 t: precision:  90.86%; recall:  85.21%; FB1:  87.94  1389
#
#                 z: precision:  27.72%; recall:  15.36%; FB1:  19.77  184
#
# Epoch 12/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.9614 - crf_accuracy: 0.9020
# processed 59449 tokens with 6198 phrases; found: 5790 phrases; correct: 4663.
#
# accuracy:  91.41%; precision:  80.54%; recall:  75.23%; FB1:  77.79
#
#                 b: precision:  61.21%; recall:  51.53%; FB1:  55.96  165
#
#                 j: precision:  84.85%; recall:  86.32%; FB1:  85.58  2238
#
#                 s: precision:  74.16%; recall:  67.37%; FB1:  70.60  1807
#
#                 t: precision:  91.47%; recall:  85.42%; FB1:  88.34  1383
#
#                 z: precision:  29.44%; recall:  17.47%; FB1:  21.93  197
#
# Epoch 13/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.9496 - crf_accuracy: 0.9062
# processed 59449 tokens with 6198 phrases; found: 5699 phrases; correct: 4699.
#
# accuracy:  91.77%; precision:  82.45%; recall:  75.81%; FB1:  78.99
#
#                 b: precision:  60.62%; recall:  49.49%; FB1:  54.49  160
#
#                 j: precision:  88.79%; recall:  86.41%; FB1:  87.58  2141
#
#                 s: precision:  75.46%; recall:  66.62%; FB1:  70.76  1756
#
#                 t: precision:  91.54%; recall:  88.45%; FB1:  89.97  1431
#
#                 z: precision:  31.28%; recall:  19.88%; FB1:  24.31  211
#
# Epoch 14/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.9341 - crf_accuracy: 0.9100
# processed 59449 tokens with 6198 phrases; found: 5575 phrases; correct: 4666.
#
# accuracy:  91.73%; precision:  83.70%; recall:  75.28%; FB1:  79.27
#
#                 b: precision:  64.15%; recall:  52.04%; FB1:  57.46  159
#
#                 j: precision:  88.96%; recall:  85.73%; FB1:  87.31  2120
#
#                 s: precision:  77.05%; recall:  66.16%; FB1:  71.19  1708
#
#                 t: precision:  93.03%; recall:  86.50%; FB1:  89.64  1377
#
#                 z: precision:  38.39%; recall:  24.40%; FB1:  29.83  211
#
# Epoch 15/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.9258 - crf_accuracy: 0.9117
# processed 59449 tokens with 6198 phrases; found: 5825 phrases; correct: 4840.
#
# accuracy:  92.30%; precision:  83.09%; recall:  78.09%; FB1:  80.51
#
#                 b: precision:  73.88%; recall:  50.51%; FB1:  60.00  134
#
#                 j: precision:  89.50%; recall:  87.55%; FB1:  88.51  2152
#
#                 s: precision:  75.19%; recall:  69.48%; FB1:  72.22  1838
#
#                 t: precision:  90.11%; recall:  89.80%; FB1:  89.96  1476
#
#                 z: precision:  45.78%; recall:  31.02%; FB1:  36.98  225
#
# Epoch 16/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.9167 - crf_accuracy: 0.9145
# processed 59449 tokens with 6198 phrases; found: 5798 phrases; correct: 4842.
#
# accuracy:  92.46%; precision:  83.51%; recall:  78.12%; FB1:  80.73
#
#                 b: precision:  68.79%; recall:  55.10%; FB1:  61.19  157
#
#                 j: precision:  89.39%; recall:  87.68%; FB1:  88.53  2158
#
#                 s: precision:  76.27%; recall:  69.33%; FB1:  72.64  1808
#
#                 t: precision:  91.16%; recall:  89.13%; FB1:  90.13  1448
#
#                 z: precision:  46.70%; recall:  31.93%; FB1:  37.92  227
#
# Epoch 17/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.9098 - crf_accuracy: 0.9179
# processed 59449 tokens with 6198 phrases; found: 5841 phrases; correct: 4892.
#
# accuracy:  92.71%; precision:  83.75%; recall:  78.93%; FB1:  81.27
#
#                 b: precision:  73.38%; recall:  57.65%; FB1:  64.57  154
#
#                 j: precision:  88.54%; recall:  88.82%; FB1:  88.68  2207
#
#                 s: precision:  76.49%; recall:  69.83%; FB1:  73.01  1816
#
#                 t: precision:  91.74%; recall:  89.20%; FB1:  90.45  1440
#
#                 z: precision:  51.34%; recall:  34.64%; FB1:  41.37  224
#
# Epoch 18/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.9014 - crf_accuracy: 0.9190
# processed 59449 tokens with 6198 phrases; found: 5766 phrases; correct: 4884.
#
# accuracy:  92.70%; precision:  84.70%; recall:  78.80%; FB1:  81.64
#
#                 b: precision:  75.18%; recall:  54.08%; FB1:  62.91  141
#
#                 j: precision:  90.45%; recall:  88.68%; FB1:  89.56  2157
#
#                 s: precision:  77.46%; recall:  69.63%; FB1:  73.34  1788
#
#                 t: precision:  90.96%; recall:  90.34%; FB1:  90.65  1471
#
#                 z: precision:  49.76%; recall:  31.33%; FB1:  38.45  209
#
# Epoch 19/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.8950 - crf_accuracy: 0.9204
# processed 59449 tokens with 6198 phrases; found: 5786 phrases; correct: 4930.
#
# accuracy:  92.99%; precision:  85.21%; recall:  79.54%; FB1:  82.28
#
#                 b: precision:  69.14%; recall:  57.14%; FB1:  62.57  162
#
#                 j: precision:  91.14%; recall:  89.73%; FB1:  90.43  2166
#
#                 s: precision:  77.54%; recall:  71.69%; FB1:  74.50  1839
#
#                 t: precision:  93.20%; recall:  87.98%; FB1:  90.52  1398
#
#                 z: precision:  52.04%; recall:  34.64%; FB1:  41.59  221
#
# Epoch 20/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.8901 - crf_accuracy: 0.9226
# processed 59449 tokens with 6198 phrases; found: 5807 phrases; correct: 4985.
#
# accuracy:  93.05%; precision:  85.84%; recall:  80.43%; FB1:  83.05
#
#                 b: precision:  73.25%; recall:  58.67%; FB1:  65.16  157
#
#                 j: precision:  91.48%; recall:  89.77%; FB1:  90.62  2159
#
#                 s: precision:  78.62%; recall:  73.20%; FB1:  75.81  1852
#
#                 t: precision:  92.68%; recall:  89.80%; FB1:  91.22  1435
#
#                 z: precision:  53.43%; recall:  32.83%; FB1:  40.67  204
#
# Epoch 21/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.8835 - crf_accuracy: 0.9247
# processed 59449 tokens with 6198 phrases; found: 5599 phrases; correct: 4863.
#
# accuracy:  92.88%; precision:  86.85%; recall:  78.46%; FB1:  82.44
#
#                 b: precision:  77.24%; recall:  57.14%; FB1:  65.69  145
#
#                 j: precision:  92.66%; recall:  87.82%; FB1:  90.18  2085
#
#                 s: precision:  79.45%; recall:  71.54%; FB1:  75.29  1791
#
#                 t: precision:  95.02%; recall:  85.08%; FB1:  89.78  1326
#
#                 z: precision:  53.97%; recall:  40.96%; FB1:  46.58  252
#
# Epoch 22/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.8776 - crf_accuracy: 0.9266
# processed 59449 tokens with 6198 phrases; found: 5880 phrases; correct: 4996.
#
# accuracy:  93.16%; precision:  84.97%; recall:  80.61%; FB1:  82.73
#
#                 b: precision:  72.22%; recall:  59.69%; FB1:  65.36  162
#
#                 j: precision:  88.50%; recall:  90.64%; FB1:  89.56  2253
#
#                 s: precision:  79.35%; recall:  71.09%; FB1:  74.99  1782
#
#                 t: precision:  92.77%; recall:  90.14%; FB1:  91.44  1439
#
#                 z: precision:  55.74%; recall:  40.96%; FB1:  47.22  244
#
# Epoch 23/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.8722 - crf_accuracy: 0.9291
# processed 59449 tokens with 6198 phrases; found: 5857 phrases; correct: 5064.
#
# accuracy:  93.48%; precision:  86.46%; recall:  81.70%; FB1:  84.01
#
#                 b: precision:  71.76%; recall:  62.24%; FB1:  66.67  170
#
#                 j: precision:  91.62%; recall:  90.95%; FB1:  91.29  2184
#
#                 s: precision:  80.52%; recall:  73.15%; FB1:  76.66  1807
#
#                 t: precision:  93.01%; recall:  90.68%; FB1:  91.83  1444
#
#                 z: precision:  56.75%; recall:  43.07%; FB1:  48.97  252
#
# Epoch 24/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.8664 - crf_accuracy: 0.9297
# processed 59449 tokens with 6198 phrases; found: 5841 phrases; correct: 5054.
#
# accuracy:  93.49%; precision:  86.53%; recall:  81.54%; FB1:  83.96
#
#                 b: precision:  71.26%; recall:  60.71%; FB1:  65.56  167
#
#                 j: precision:  91.22%; recall:  91.09%; FB1:  91.15  2197
#
#                 s: precision:  80.18%; recall:  73.40%; FB1:  76.64  1821
#
#                 t: precision:  94.35%; recall:  89.06%; FB1:  91.63  1398
#
#                 z: precision:  58.91%; recall:  45.78%; FB1:  51.53  258
#
# Epoch 25/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.8670 - crf_accuracy: 0.9283
# processed 59449 tokens with 6198 phrases; found: 5802 phrases; correct: 5051.
#
# accuracy:  93.55%; precision:  87.06%; recall:  81.49%; FB1:  84.18
#
#                 b: precision:  75.48%; recall:  59.69%; FB1:  66.67  155
#
#                 j: precision:  91.49%; recall:  91.82%; FB1:  91.65  2208
#
#                 s: precision:  80.83%; recall:  72.30%; FB1:  76.33  1779
#
#                 t: precision:  94.03%; recall:  89.26%; FB1:  91.58  1406
#
#                 z: precision:  60.63%; recall:  46.39%; FB1:  52.56  254
#
# Epoch 26/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.8599 - crf_accuracy: 0.9315
# processed 59449 tokens with 6198 phrases; found: 5742 phrases; correct: 5053.
#
# accuracy:  93.59%; precision:  88.00%; recall:  81.53%; FB1:  84.64
#
#                 b: precision:  82.44%; recall:  55.10%; FB1:  66.06  131
#
#                 j: precision:  92.27%; recall:  91.09%; FB1:  91.67  2172
#
#                 s: precision:  81.28%; recall:  73.15%; FB1:  77.00  1790
#
#                 t: precision:  94.11%; recall:  89.53%; FB1:  91.76  1409
#
#                 z: precision:  66.67%; recall:  48.19%; FB1:  55.94  240
#
# Epoch 27/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.8583 - crf_accuracy: 0.9317
# processed 59449 tokens with 6198 phrases; found: 5943 phrases; correct: 5137.
#
# accuracy:  93.85%; precision:  86.44%; recall:  82.88%; FB1:  84.62
#
#                 b: precision:  71.93%; recall:  62.76%; FB1:  67.03  171
#
#                 j: precision:  92.02%; recall:  92.73%; FB1:  92.37  2217
#
#                 s: precision:  78.82%; recall:  72.60%; FB1:  75.58  1832
#
#                 t: precision:  93.10%; recall:  91.15%; FB1:  92.12  1450
#
#                 z: precision:  65.93%; recall:  54.22%; FB1:  59.50  273
#
# Epoch 28/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.8544 - crf_accuracy: 0.9343
# processed 59449 tokens with 6198 phrases; found: 5846 phrases; correct: 5109.
#
# accuracy:  93.78%; precision:  87.39%; recall:  82.43%; FB1:  84.84
#
#                 b: precision:  75.78%; recall:  62.24%; FB1:  68.35  161
#
#                 j: precision:  92.15%; recall:  92.32%; FB1:  92.23  2204
#
#                 s: precision:  81.29%; recall:  72.75%; FB1:  76.78  1780
#
#                 t: precision:  93.73%; recall:  90.88%; FB1:  92.29  1436
#
#                 z: precision:  61.51%; recall:  49.10%; FB1:  54.61  265
#
# Epoch 29/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.8518 - crf_accuracy: 0.9350
# processed 59449 tokens with 6198 phrases; found: 5943 phrases; correct: 5175.
#
# accuracy:  93.94%; precision:  87.08%; recall:  83.49%; FB1:  85.25
#
#                 b: precision:  76.05%; recall:  64.80%; FB1:  69.97  167
#
#                 j: precision:  91.68%; recall:  92.64%; FB1:  92.15  2223
#
#                 s: precision:  80.30%; recall:  74.41%; FB1:  77.24  1843
#
#                 t: precision:  93.40%; recall:  91.69%; FB1:  92.54  1454
#
#                 z: precision:  67.19%; recall:  51.81%; FB1:  58.50  256
#
# Epoch 30/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.8513 - crf_accuracy: 0.9342
# processed 59449 tokens with 6198 phrases; found: 5966 phrases; correct: 5186.
#
# accuracy:  93.98%; precision:  86.93%; recall:  83.67%; FB1:  85.27
#
#                 b: precision:  76.07%; recall:  63.27%; FB1:  69.08  163
#
#                 j: precision:  92.43%; recall:  92.73%; FB1:  92.58  2207
#
#                 s: precision:  80.06%; recall:  74.91%; FB1:  77.40  1861
#
#                 t: precision:  92.96%; recall:  91.90%; FB1:  92.43  1464
#
#                 z: precision:  63.10%; recall:  51.51%; FB1:  56.72  271
#
# Epoch 31/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.8469 - crf_accuracy: 0.9379
# processed 59449 tokens with 6198 phrases; found: 5979 phrases; correct: 5157.
#
# accuracy:  93.79%; precision:  86.25%; recall:  83.20%; FB1:  84.70
#
#                 b: precision:  78.62%; recall:  63.78%; FB1:  70.42  159
#
#                 j: precision:  92.21%; recall:  93.09%; FB1:  92.65  2221
#
#                 s: precision:  80.24%; recall:  74.31%; FB1:  77.16  1842
#
#                 t: precision:  92.77%; recall:  91.83%; FB1:  92.30  1466
#
#                 z: precision:  50.17%; recall:  43.98%; FB1:  46.87  291
#
# Epoch 32/120
# Epoch 1/1
# 3543/3543 [==============================] - 30s 8ms/step - loss: 26.8438 - crf_accuracy: 0.9380
# processed 59449 tokens with 6198 phrases; found: 6074 phrases; correct: 5263.
#
# accuracy:  94.14%; precision:  86.65%; recall:  84.91%; FB1:  85.77
#
#                 b: precision:  77.64%; recall:  63.78%; FB1:  70.03  161
#
#                 j: precision:  92.12%; recall:  93.55%; FB1:  92.83  2234
#
#                 s: precision:  80.61%; recall:  76.52%; FB1:  78.51  1888
#
#                 t: precision:  91.05%; recall:  93.38%; FB1:  92.20  1519
#
#                 z: precision:  64.34%; recall:  52.71%; FB1:  57.95  272
#
# Epoch 33/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.8421 - crf_accuracy: 0.9378
# processed 59449 tokens with 6198 phrases; found: 5928 phrases; correct: 5176.
#
# accuracy:  94.03%; precision:  87.31%; recall:  83.51%; FB1:  85.37
#
#                 b: precision:  66.17%; recall:  67.86%; FB1:  67.00  201
#
#                 j: precision:  92.83%; recall:  92.95%; FB1:  92.89  2203
#
#                 s: precision:  80.57%; recall:  73.40%; FB1:  76.82  1812
#
#                 t: precision:  94.38%; recall:  90.75%; FB1:  92.53  1424
#
#                 z: precision:  67.36%; recall:  58.43%; FB1:  62.58  288
#
# Epoch 34/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.8389 - crf_accuracy: 0.9394
# processed 59449 tokens with 6198 phrases; found: 5990 phrases; correct: 5228.
#
# accuracy:  94.31%; precision:  87.28%; recall:  84.35%; FB1:  85.79
#
#                 b: precision:  73.94%; recall:  62.24%; FB1:  67.59  165
#
#                 j: precision:  92.72%; recall:  93.27%; FB1:  93.00  2213
#
#                 s: precision:  80.18%; recall:  75.67%; FB1:  77.86  1877
#
#                 t: precision:  93.40%; recall:  91.76%; FB1:  92.57  1455
#
#                 z: precision:  67.86%; recall:  57.23%; FB1:  62.09  280
#
# Epoch 35/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.8376 - crf_accuracy: 0.9409
# processed 59449 tokens with 6198 phrases; found: 5946 phrases; correct: 5221.
#
# accuracy:  94.33%; precision:  87.81%; recall:  84.24%; FB1:  85.98
#
#                 b: precision:  78.18%; recall:  65.82%; FB1:  71.47  165
#
#                 j: precision:  92.24%; recall:  93.41%; FB1:  92.82  2228
#
#                 s: precision:  81.93%; recall:  75.67%; FB1:  78.67  1837
#
#                 t: precision:  93.95%; recall:  91.15%; FB1:  92.53  1437
#
#                 z: precision:  65.23%; recall:  54.82%; FB1:  59.57  279
#
# Epoch 36/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.8364 - crf_accuracy: 0.9418
# processed 59449 tokens with 6198 phrases; found: 5935 phrases; correct: 5232.
#
# accuracy:  94.36%; precision:  88.16%; recall:  84.41%; FB1:  86.24
#
#                 b: precision:  80.26%; recall:  62.24%; FB1:  70.11  152
#
#                 j: precision:  93.89%; recall:  92.95%; FB1:  93.42  2178
#
#                 s: precision:  79.45%; recall:  75.82%; FB1:  77.59  1898
#
#                 t: precision:  94.35%; recall:  91.29%; FB1:  92.79  1433
#
#                 z: precision:  74.82%; recall:  61.75%; FB1:  67.66  274
#
# Epoch 37/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.8318 - crf_accuracy: 0.9420
# processed 59449 tokens with 6198 phrases; found: 5931 phrases; correct: 5221.
#
# accuracy:  94.25%; precision:  88.03%; recall:  84.24%; FB1:  86.09
#
#                 b: precision:  77.11%; recall:  65.31%; FB1:  70.72  166
#
#                 j: precision:  93.35%; recall:  92.59%; FB1:  92.97  2182
#
#                 s: precision:  81.57%; recall:  75.87%; FB1:  78.61  1850
#
#                 t: precision:  93.20%; recall:  91.56%; FB1:  92.37  1455
#
#                 z: precision:  68.71%; recall:  57.53%; FB1:  62.62  278
#
# Epoch 38/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.8309 - crf_accuracy: 0.9436
# processed 59449 tokens with 6198 phrases; found: 5814 phrases; correct: 5166.
#
# accuracy:  94.07%; precision:  88.85%; recall:  83.35%; FB1:  86.01
#
#                 b: precision:  83.33%; recall:  63.78%; FB1:  72.25  150
#
#                 j: precision:  93.23%; recall:  92.68%; FB1:  92.96  2187
#
#                 s: precision:  81.89%; recall:  75.47%; FB1:  78.55  1833
#
#                 t: precision:  95.52%; recall:  87.85%; FB1:  91.52  1362
#
#                 z: precision:  70.92%; recall:  60.24%; FB1:  65.15  282
#
# Epoch 39/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.8291 - crf_accuracy: 0.9426
# processed 59449 tokens with 6198 phrases; found: 6024 phrases; correct: 5281.
#
# accuracy:  94.40%; precision:  87.67%; recall:  85.20%; FB1:  86.42
#
#                 b: precision:  73.08%; recall:  67.86%; FB1:  70.37  182
#
#                 j: precision:  92.00%; recall:  93.55%; FB1:  92.77  2237
#
#                 s: precision:  81.25%; recall:  76.27%; FB1:  78.68  1867
#
#                 t: precision:  93.68%; recall:  92.03%; FB1:  92.85  1455
#
#                 z: precision:  74.20%; recall:  63.25%; FB1:  68.29  283
#
# Epoch 40/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.8275 - crf_accuracy: 0.9436
# processed 59449 tokens with 6198 phrases; found: 6086 phrases; correct: 5306.
#
# accuracy:  94.43%; precision:  87.18%; recall:  85.61%; FB1:  86.39
#
#                 b: precision:  70.62%; recall:  69.90%; FB1:  70.26  194
#
#                 j: precision:  92.36%; recall:  94.00%; FB1:  93.17  2239
#
#                 s: precision:  80.21%; recall:  76.22%; FB1:  78.16  1890
#
#                 t: precision:  93.52%; recall:  92.57%; FB1:  93.04  1466
#
#                 z: precision:  72.05%; recall:  64.46%; FB1:  68.04  297
#
# Epoch 41/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.8262 - crf_accuracy: 0.9447
# processed 59449 tokens with 6198 phrases; found: 6142 phrases; correct: 5302.
#
# accuracy:  94.13%; precision:  86.32%; recall:  85.54%; FB1:  85.93
#
#                 b: precision:  59.91%; recall:  70.92%; FB1:  64.95  232
#
#                 j: precision:  91.77%; recall:  94.23%; FB1:  92.98  2259
#
#                 s: precision:  81.47%; recall:  76.02%; FB1:  78.65  1856
#
#                 t: precision:  92.56%; recall:  93.25%; FB1:  92.90  1492
#
#                 z: precision:  65.02%; recall:  59.34%; FB1:  62.05  303
#
# Epoch 42/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.8257 - crf_accuracy: 0.9446
# processed 59449 tokens with 6198 phrases; found: 5990 phrases; correct: 5260.
#
# accuracy:  94.43%; precision:  87.81%; recall:  84.87%; FB1:  86.31
#
#                 b: precision:  74.18%; recall:  68.88%; FB1:  71.43  182
#
#                 j: precision:  92.47%; recall:  93.77%; FB1:  93.12  2231
#
#                 s: precision:  80.65%; recall:  75.41%; FB1:  77.94  1860
#
#                 t: precision:  94.72%; recall:  90.88%; FB1:  92.76  1421
#
#                 z: precision:  72.97%; recall:  65.06%; FB1:  68.79  296
#
# Epoch 43/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.8230 - crf_accuracy: 0.9455
# processed 59449 tokens with 6198 phrases; found: 6044 phrases; correct: 5274.
#
# accuracy:  94.36%; precision:  87.26%; recall:  85.09%; FB1:  86.16
#
#                 b: precision:  77.65%; recall:  70.92%; FB1:  74.13  179
#
#                 j: precision:  93.12%; recall:  93.55%; FB1:  93.33  2210
#
#                 s: precision:  80.56%; recall:  77.28%; FB1:  78.88  1908
#
#                 t: precision:  93.69%; recall:  92.23%; FB1:  92.96  1458
#
#                 z: precision:  60.21%; recall:  52.41%; FB1:  56.04  289
#
# Epoch 44/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.8211 - crf_accuracy: 0.9478
# processed 59449 tokens with 6198 phrases; found: 6010 phrases; correct: 5277.
#
# accuracy:  94.39%; precision:  87.80%; recall:  85.14%; FB1:  86.45
#
#                 b: precision:  83.03%; recall:  69.90%; FB1:  75.90  165
#
#                 j: precision:  92.95%; recall:  94.09%; FB1:  93.52  2227
#
#                 s: precision:  81.28%; recall:  76.62%; FB1:  78.88  1875
#
#                 t: precision:  94.30%; recall:  92.71%; FB1:  93.50  1456
#
#                 z: precision:  60.28%; recall:  52.11%; FB1:  55.90  287
#
# Epoch 45/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.8212 - crf_accuracy: 0.9469
# processed 59449 tokens with 6198 phrases; found: 6047 phrases; correct: 5281.
#
# accuracy:  94.49%; precision:  87.33%; recall:  85.20%; FB1:  86.26
#
#                 b: precision:  82.61%; recall:  67.86%; FB1:  74.51  161
#
#                 j: precision:  93.15%; recall:  93.32%; FB1:  93.23  2204
#
#                 s: precision:  78.67%; recall:  76.42%; FB1:  77.53  1932
#
#                 t: precision:  93.75%; recall:  92.23%; FB1:  92.99  1457
#
#                 z: precision:  71.33%; recall:  62.95%; FB1:  66.88  293
#
# Epoch 46/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.8190 - crf_accuracy: 0.9477
# processed 59449 tokens with 6198 phrases; found: 5845 phrases; correct: 5233.
#
# accuracy:  94.41%; precision:  89.53%; recall:  84.43%; FB1:  86.91
#
#                 b: precision:  86.67%; recall:  66.33%; FB1:  75.14  150
#
#                 j: precision:  94.12%; recall:  93.09%; FB1:  93.60  2176
#
#                 s: precision:  83.38%; recall:  75.92%; FB1:  79.47  1811
#
#                 t: precision:  95.25%; recall:  90.75%; FB1:  92.95  1411
#
#                 z: precision:  67.68%; recall:  60.54%; FB1:  63.91  297
#
# Epoch 47/120
# Epoch 1/1
# 3543/3543 [==============================] - 30s 9ms/step - loss: 26.8186 - crf_accuracy: 0.9474
# processed 59449 tokens with 6198 phrases; found: 5968 phrases; correct: 5292.
#
# accuracy:  94.50%; precision:  88.67%; recall:  85.38%; FB1:  87.00
#
#                 b: precision:  75.71%; recall:  68.37%; FB1:  71.85  177
#
#                 j: precision:  93.79%; recall:  93.36%; FB1:  93.58  2190
#
#                 s: precision:  82.31%; recall:  76.27%; FB1:  79.18  1843
#
#                 t: precision:  93.78%; recall:  92.57%; FB1:  93.17  1462
#
#                 z: precision:  72.97%; recall:  65.06%; FB1:  68.79  296
#
# Epoch 48/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.8164 - crf_accuracy: 0.9487
# processed 59449 tokens with 6198 phrases; found: 6055 phrases; correct: 5328.
#
# accuracy:  94.49%; precision:  87.99%; recall:  85.96%; FB1:  86.97
#
#                 b: precision:  80.92%; recall:  71.43%; FB1:  75.88  173
#
#                 j: precision:  91.98%; recall:  93.86%; FB1:  92.91  2245
#
#                 s: precision:  80.99%; recall:  77.33%; FB1:  79.12  1899
#
#                 t: precision:  94.11%; recall:  92.71%; FB1:  93.40  1459
#
#                 z: precision:  75.99%; recall:  63.86%; FB1:  69.39  279
#
# Epoch 49/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.8142 - crf_accuracy: 0.9488
# processed 59449 tokens with 6198 phrases; found: 5974 phrases; correct: 5326.
#
# accuracy:  94.61%; precision:  89.15%; recall:  85.93%; FB1:  87.51
#
#                 b: precision:  83.95%; recall:  69.39%; FB1:  75.98  162
#
#                 j: precision:  93.79%; recall:  94.09%; FB1:  93.94  2207
#
#                 s: precision:  82.54%; recall:  76.27%; FB1:  79.28  1838
#
#                 t: precision:  93.94%; recall:  93.18%; FB1:  93.56  1469
#
#                 z: precision:  74.83%; recall:  67.17%; FB1:  70.79  298
#
# Epoch 50/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.8143 - crf_accuracy: 0.9500
# processed 59449 tokens with 6198 phrases; found: 6092 phrases; correct: 5332.
#
# accuracy:  94.42%; precision:  87.52%; recall:  86.03%; FB1:  86.77
#
#                 b: precision:  77.60%; recall:  72.45%; FB1:  74.93  183
#
#                 j: precision:  89.93%; recall:  93.41%; FB1:  91.64  2285
#
#                 s: precision:  82.31%; recall:  76.97%; FB1:  79.55  1860
#
#                 t: precision:  93.71%; recall:  93.59%; FB1:  93.65  1479
#
#                 z: precision:  76.49%; recall:  65.66%; FB1:  70.66  285
#
# Epoch 51/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.8130 - crf_accuracy: 0.9505
# processed 59449 tokens with 6198 phrases; found: 6091 phrases; correct: 5345.
#
# accuracy:  94.61%; precision:  87.75%; recall:  86.24%; FB1:  86.99
#
#                 b: precision:  84.15%; recall:  70.41%; FB1:  76.67  164
#
#                 j: precision:  93.16%; recall:  94.09%; FB1:  93.62  2222
#
#                 s: precision:  80.42%; recall:  78.28%; FB1:  79.34  1936
#
#                 t: precision:  94.11%; recall:  92.84%; FB1:  93.47  1461
#
#                 z: precision:  66.56%; recall:  61.75%; FB1:  64.06  308
#
# Epoch 52/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.8123 - crf_accuracy: 0.9505
# processed 59449 tokens with 6198 phrases; found: 5960 phrases; correct: 5303.
#
# accuracy:  94.62%; precision:  88.98%; recall:  85.56%; FB1:  87.23
#
#                 b: precision:  77.53%; recall:  70.41%; FB1:  73.80  178
#
#                 j: precision:  93.44%; recall:  93.86%; FB1:  93.65  2210
#
#                 s: precision:  82.30%; recall:  75.77%; FB1:  78.90  1831
#
#                 t: precision:  94.54%; recall:  92.44%; FB1:  93.48  1448
#
#                 z: precision:  76.45%; recall:  67.47%; FB1:  71.68  293
#
# Epoch 53/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.8109 - crf_accuracy: 0.9502
# processed 59449 tokens with 6198 phrases; found: 6043 phrases; correct: 5329.
#
# accuracy:  94.54%; precision:  88.18%; recall:  85.98%; FB1:  87.07
#
#                 b: precision:  74.33%; recall:  70.92%; FB1:  72.58  187
#
#                 j: precision:  91.32%; recall:  94.18%; FB1:  92.73  2269
#
#                 s: precision:  83.01%; recall:  76.17%; FB1:  79.44  1825
#
#                 t: precision:  94.39%; recall:  93.18%; FB1:  93.78  1462
#
#                 z: precision:  74.33%; recall:  67.17%; FB1:  70.57  300
#
# Epoch 54/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.8099 - crf_accuracy: 0.9509
# processed 59449 tokens with 6198 phrases; found: 6067 phrases; correct: 5374.
#
# accuracy:  94.76%; precision:  88.58%; recall:  86.71%; FB1:  87.63
#
#                 b: precision:  78.09%; recall:  70.92%; FB1:  74.33  178
#
#                 j: precision:  93.63%; recall:  94.23%; FB1:  93.93  2214
#
#                 s: precision:  81.44%; recall:  77.88%; FB1:  79.62  1902
#
#                 t: precision:  94.03%; recall:  93.59%; FB1:  93.81  1474
#
#                 z: precision:  75.92%; recall:  68.37%; FB1:  71.95  299
#
# Epoch 55/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.8090 - crf_accuracy: 0.9501
# processed 59449 tokens with 6198 phrases; found: 6027 phrases; correct: 5359.
#
# accuracy:  94.87%; precision:  88.92%; recall:  86.46%; FB1:  87.67
#
#                 b: precision:  85.35%; recall:  68.37%; FB1:  75.92  157
#
#                 j: precision:  93.48%; recall:  94.45%; FB1:  93.96  2223
#
#                 s: precision:  81.21%; recall:  77.78%; FB1:  79.46  1905
#
#                 t: precision:  94.82%; recall:  92.64%; FB1:  93.72  1447
#
#                 z: precision:  77.29%; recall:  68.67%; FB1:  72.73  295
#
# Epoch 56/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.8076 - crf_accuracy: 0.9521
# processed 59449 tokens with 6198 phrases; found: 6164 phrases; correct: 5410.
#
# accuracy:  94.77%; precision:  87.77%; recall:  87.29%; FB1:  87.53
#
#                 b: precision:  77.01%; recall:  73.47%; FB1:  75.20  187
#
#                 j: precision:  93.25%; recall:  94.82%; FB1:  94.03  2237
#
#                 s: precision:  80.69%; recall:  77.73%; FB1:  79.18  1916
#
#                 t: precision:  92.47%; recall:  95.41%; FB1:  93.92  1528
#
#                 z: precision:  74.66%; recall:  66.57%; FB1:  70.38  296
#
# Epoch 57/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.8085 - crf_accuracy: 0.9514
# processed 59449 tokens with 6198 phrases; found: 6104 phrases; correct: 5401.
#
# accuracy:  94.92%; precision:  88.48%; recall:  87.14%; FB1:  87.81
#
#                 b: precision:  83.14%; recall:  72.96%; FB1:  77.72  172
#
#                 j: precision:  93.60%; recall:  94.41%; FB1:  94.00  2219
#
#                 s: precision:  80.91%; recall:  79.03%; FB1:  79.96  1943
#
#                 t: precision:  94.15%; recall:  93.45%; FB1:  93.80  1470
#
#                 z: precision:  75.00%; recall:  67.77%; FB1:  71.20  300
#
# Epoch 58/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.8072 - crf_accuracy: 0.9524
# processed 59449 tokens with 6198 phrases; found: 5980 phrases; correct: 5344.
#
# accuracy:  94.69%; precision:  89.36%; recall:  86.22%; FB1:  87.76
#
#                 b: precision:  78.77%; recall:  71.94%; FB1:  75.20  179
#
#                 j: precision:  93.98%; recall:  94.45%; FB1:  94.22  2211
#
#                 s: precision:  83.37%; recall:  76.87%; FB1:  79.99  1834
#
#                 t: precision:  94.62%; recall:  92.64%; FB1:  93.62  1450
#
#                 z: precision:  73.20%; recall:  67.47%; FB1:  70.22  306
#
# Epoch 59/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.8054 - crf_accuracy: 0.9510
# processed 59449 tokens with 6198 phrases; found: 6007 phrases; correct: 5353.
#
# accuracy:  94.68%; precision:  89.11%; recall:  86.37%; FB1:  87.72
#
#                 b: precision:  80.11%; recall:  71.94%; FB1:  75.81  176
#
#                 j: precision:  94.17%; recall:  93.23%; FB1:  93.70  2178
#
#                 s: precision:  81.91%; recall:  77.63%; FB1:  79.71  1885
#
#                 t: precision:  94.23%; recall:  93.72%; FB1:  93.97  1473
#
#                 z: precision:  77.63%; recall:  68.98%; FB1:  73.05  295
#
# Epoch 60/120
# Epoch 1/1
# 3543/3543 [==============================] - 30s 8ms/step - loss: 26.8048 - crf_accuracy: 0.9527
# processed 59449 tokens with 6198 phrases; found: 5940 phrases; correct: 5285.
#
# accuracy:  94.52%; precision:  88.97%; recall:  85.27%; FB1:  87.08
#
#                 b: precision:  85.28%; recall:  70.92%; FB1:  77.44  163
#
#                 j: precision:  94.64%; recall:  92.27%; FB1:  93.44  2145
#
#                 s: precision:  80.10%; recall:  77.12%; FB1:  78.59  1915
#
#                 t: precision:  95.14%; recall:  91.29%; FB1:  93.18  1421
#
#                 z: precision:  77.70%; recall:  69.28%; FB1:  73.25  296
#
# Epoch 61/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.8034 - crf_accuracy: 0.9540
# processed 59449 tokens with 6198 phrases; found: 5938 phrases; correct: 5330.
#
# accuracy:  94.84%; precision:  89.76%; recall:  86.00%; FB1:  87.84
#
#                 b: precision:  83.23%; recall:  70.92%; FB1:  76.58  167
#
#                 j: precision:  93.97%; recall:  94.18%; FB1:  94.07  2205
#
#                 s: precision:  83.21%; recall:  76.47%; FB1:  79.70  1828
#
#                 t: precision:  94.86%; recall:  92.30%; FB1:  93.57  1441
#
#                 z: precision:  77.78%; recall:  69.58%; FB1:  73.45  297
#
# Epoch 62/120
# Epoch 1/1
# 3543/3543 [==============================] - 30s 8ms/step - loss: 26.8028 - crf_accuracy: 0.9535
# processed 59449 tokens with 6198 phrases; found: 6130 phrases; correct: 5426.
#
# accuracy:  94.84%; precision:  88.52%; recall:  87.54%; FB1:  88.03
#
#                 b: precision:  84.94%; recall:  71.94%; FB1:  77.90  166
#
#                 j: precision:  92.51%; recall:  94.82%; FB1:  93.65  2255
#
#                 s: precision:  82.08%; recall:  78.78%; FB1:  80.40  1909
#
#                 t: precision:  93.58%; recall:  94.53%; FB1:  94.05  1496
#
#                 z: precision:  76.32%; recall:  69.88%; FB1:  72.96  304
#
# Epoch 63/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.8035 - crf_accuracy: 0.9531
# processed 59449 tokens with 6198 phrases; found: 6020 phrases; correct: 5365.
#
# accuracy:  94.85%; precision:  89.12%; recall:  86.56%; FB1:  87.82
#
#                 b: precision:  75.40%; recall:  71.94%; FB1:  73.63  187
#
#                 j: precision:  92.38%; recall:  94.23%; FB1:  93.29  2244
#
#                 s: precision:  83.72%; recall:  77.02%; FB1:  80.23  1830
#
#                 t: precision:  94.65%; recall:  93.25%; FB1:  93.95  1459
#
#                 z: precision:  79.33%; recall:  71.69%; FB1:  75.32  300
#
# Epoch 64/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.8026 - crf_accuracy: 0.9546
# processed 59449 tokens with 6198 phrases; found: 5954 phrases; correct: 5356.
#
# accuracy:  94.84%; precision:  89.96%; recall:  86.41%; FB1:  88.15
#
#                 b: precision:  82.93%; recall:  69.39%; FB1:  75.56  164
#
#                 j: precision:  94.08%; recall:  93.91%; FB1:  93.99  2196
#
#                 s: precision:  83.26%; recall:  77.53%; FB1:  80.29  1852
#
#                 t: precision:  94.90%; recall:  92.91%; FB1:  93.89  1450
#
#                 z: precision:  80.82%; recall:  71.08%; FB1:  75.64  292
#
# Epoch 65/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.8006 - crf_accuracy: 0.9553
# processed 59449 tokens with 6198 phrases; found: 5968 phrases; correct: 5340.
#
# accuracy:  94.81%; precision:  89.48%; recall:  86.16%; FB1:  87.79
#
#                 b: precision:  82.42%; recall:  69.39%; FB1:  75.35  165
#
#                 j: precision:  94.06%; recall:  94.32%; FB1:  94.19  2206
#
#                 s: precision:  82.15%; recall:  77.07%; FB1:  79.53  1866
#
#                 t: precision:  94.66%; recall:  92.23%; FB1:  93.43  1443
#
#                 z: precision:  79.86%; recall:  69.28%; FB1:  74.19  288
#
# Epoch 66/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.7999 - crf_accuracy: 0.9556
# processed 59449 tokens with 6198 phrases; found: 5941 phrases; correct: 5317.
#
# accuracy:  94.59%; precision:  89.50%; recall:  85.79%; FB1:  87.60
#
#                 b: precision:  84.47%; recall:  69.39%; FB1:  76.19  161
#
#                 j: precision:  94.42%; recall:  93.05%; FB1:  93.73  2168
#
#                 s: precision:  81.49%; recall:  77.48%; FB1:  79.43  1891
#
#                 t: precision:  94.59%; recall:  92.10%; FB1:  93.33  1442
#
#                 z: precision:  82.08%; recall:  68.98%; FB1:  74.96  279
#
# Epoch 67/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.8002 - crf_accuracy: 0.9558
# processed 59449 tokens with 6198 phrases; found: 6057 phrases; correct: 5406.
#
# accuracy:  94.86%; precision:  89.25%; recall:  87.22%; FB1:  88.23
#
#                 b: precision:  81.07%; recall:  69.90%; FB1:  75.07  169
#
#                 j: precision:  93.25%; recall:  94.77%; FB1:  94.00  2236
#
#                 s: precision:  82.51%; recall:  77.78%; FB1:  80.07  1875
#
#                 t: precision:  94.13%; recall:  94.19%; FB1:  94.16  1482
#
#                 z: precision:  82.03%; recall:  72.89%; FB1:  77.19  295
#
# Epoch 68/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.7988 - crf_accuracy: 0.9563
# processed 59449 tokens with 6198 phrases; found: 5890 phrases; correct: 5327.
#
# accuracy:  94.72%; precision:  90.44%; recall:  85.95%; FB1:  88.14
#
#                 b: precision:  79.89%; recall:  70.92%; FB1:  75.14  174
#
#                 j: precision:  94.10%; recall:  94.23%; FB1:  94.16  2203
#
#                 s: precision:  84.47%; recall:  75.77%; FB1:  79.88  1784
#
#                 t: precision:  95.47%; recall:  92.44%; FB1:  93.93  1434
#
#                 z: precision:  81.02%; recall:  71.99%; FB1:  76.24  295
#
# Epoch 69/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.7973 - crf_accuracy: 0.9568
# processed 59449 tokens with 6198 phrases; found: 6055 phrases; correct: 5392.
#
# accuracy:  94.89%; precision:  89.05%; recall:  87.00%; FB1:  88.01
#
#                 b: precision:  81.25%; recall:  72.96%; FB1:  76.88  176
#
#                 j: precision:  93.76%; recall:  94.27%; FB1:  94.02  2212
#
#                 s: precision:  82.33%; recall:  78.03%; FB1:  80.12  1885
#
#                 t: precision:  93.73%; recall:  93.92%; FB1:  93.83  1484
#
#                 z: precision:  77.85%; recall:  69.88%; FB1:  73.65  298
#
# Epoch 70/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.7966 - crf_accuracy: 0.9572
# processed 59449 tokens with 6198 phrases; found: 5999 phrases; correct: 5376.
#
# accuracy:  94.79%; precision:  89.61%; recall:  86.74%; FB1:  88.15
#
#                 b: precision:  79.89%; recall:  72.96%; FB1:  76.27  179
#
#                 j: precision:  94.27%; recall:  93.41%; FB1:  93.84  2180
#
#                 s: precision:  82.73%; recall:  78.28%; FB1:  80.44  1882
#
#                 t: precision:  94.41%; recall:  93.45%; FB1:  93.93  1466
#
#                 z: precision:  81.16%; recall:  71.39%; FB1:  75.96  292
#
# Epoch 71/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.7964 - crf_accuracy: 0.9570
# processed 59449 tokens with 6198 phrases; found: 6278 phrases; correct: 5479.
#
# accuracy:  94.77%; precision:  87.27%; recall:  88.40%; FB1:  87.83
#
#                 b: precision:  73.71%; recall:  72.96%; FB1:  73.33  194
#
#                 j: precision:  92.69%; recall:  95.05%; FB1:  93.85  2256
#
#                 s: precision:  81.67%; recall:  80.19%; FB1:  80.92  1953
#
#                 t: precision:  90.73%; recall:  95.88%; FB1:  93.24  1565
#
#                 z: precision:  74.19%; recall:  69.28%; FB1:  71.65  310
#
# Epoch 72/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.7976 - crf_accuracy: 0.9576
# processed 59449 tokens with 6198 phrases; found: 5893 phrases; correct: 5282.
#
# accuracy:  94.43%; precision:  89.63%; recall:  85.22%; FB1:  87.37
#
#                 b: precision:  68.57%; recall:  73.47%; FB1:  70.94  210
#
#                 j: precision:  94.40%; recall:  91.23%; FB1:  92.79  2126
#
#                 s: precision:  83.57%; recall:  77.22%; FB1:  80.27  1838
#
#                 t: precision:  95.65%; recall:  92.03%; FB1:  93.81  1425
#
#                 z: precision:  78.91%; recall:  69.88%; FB1:  74.12  294
#
# Epoch 73/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.7948 - crf_accuracy: 0.9577
# processed 59449 tokens with 6198 phrases; found: 6114 phrases; correct: 5439.
#
# accuracy:  95.02%; precision:  88.96%; recall:  87.75%; FB1:  88.35
#
#                 b: precision:  77.66%; recall:  74.49%; FB1:  76.04  188
#
#                 j: precision:  92.56%; recall:  94.95%; FB1:  93.74  2257
#
#                 s: precision:  82.88%; recall:  79.08%; FB1:  80.94  1898
#
#                 t: precision:  94.63%; recall:  93.92%; FB1:  94.27  1470
#
#                 z: precision:  79.73%; recall:  72.29%; FB1:  75.83  301
#
# Epoch 74/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.7946 - crf_accuracy: 0.9578
# processed 59449 tokens with 6198 phrases; found: 6122 phrases; correct: 5425.
#
# accuracy:  95.00%; precision:  88.61%; recall:  87.53%; FB1:  88.07
#
#                 b: precision:  80.68%; recall:  72.45%; FB1:  76.34  176
#
#                 j: precision:  93.54%; recall:  94.73%; FB1:  94.13  2228
#
#                 s: precision:  81.21%; recall:  79.08%; FB1:  80.13  1937
#
#                 t: precision:  93.99%; recall:  93.92%; FB1:  93.95  1480
#
#                 z: precision:  78.07%; recall:  70.78%; FB1:  74.25  301
#
# Epoch 75/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.7938 - crf_accuracy: 0.9589
# processed 59449 tokens with 6198 phrases; found: 6078 phrases; correct: 5398.
#
# accuracy:  94.79%; precision:  88.81%; recall:  87.09%; FB1:  87.94
#
#                 b: precision:  72.36%; recall:  73.47%; FB1:  72.91  199
#
# ...
# processed 59449 tokens with 6198 phrases; found: 6209 phrases; correct: 5458.
#
# accuracy:  94.80%; precision:  87.90%; recall:  88.06%; FB1:  87.98
#
#                 b: precision:  73.37%; recall:  74.49%; FB1:  73.92  199
#
#                 j: precision:  92.97%; recall:  94.95%; FB1:  93.95  2247
#
#                 s: precision:  81.67%; recall:  79.08%; FB1:  80.36  1926
#
#                 t: precision:  92.66%; recall:  95.41%; FB1:  94.01  1525
#
#                 z: precision:  75.96%; recall:  71.39%; FB1:  73.60  312
#
# Epoch 97/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.7840 - crf_accuracy: 0.9630
# processed 59449 tokens with 6198 phrases; found: 6140 phrases; correct: 5467.
#
# accuracy:  95.14%; precision:  89.04%; recall:  88.21%; FB1:  88.62
#
#                 b: precision:  81.46%; recall:  73.98%; FB1:  77.54  178
#
#                 j: precision:  93.81%; recall:  95.05%; FB1:  94.42  2229
#
#                 s: precision:  81.42%; recall:  80.19%; FB1:  80.80  1959
#
#                 t: precision:  94.25%; recall:  93.99%; FB1:  94.12  1477
#
#                 z: precision:  82.15%; recall:  73.49%; FB1:  77.58  297
#
# Epoch 98/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.7840 - crf_accuracy: 0.9639
# processed 59449 tokens with 6198 phrases; found: 5981 phrases; correct: 5409.
#
# accuracy:  95.12%; precision:  90.44%; recall:  87.27%; FB1:  88.83
#
#                 b: precision:  76.92%; recall:  76.53%; FB1:  76.73  195
#
#                 j: precision:  94.49%; recall:  94.27%; FB1:  94.38  2195
#
#                 s: precision:  83.98%; recall:  79.34%; FB1:  81.59  1879
#
#                 t: precision:  96.25%; recall:  91.76%; FB1:  93.95  1412
#
#                 z: precision:  82.67%; recall:  74.70%; FB1:  78.48  300
#
# Epoch 99/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.7824 - crf_accuracy: 0.9647
# processed 59449 tokens with 6198 phrases; found: 5935 phrases; correct: 5390.
#
# accuracy:  95.02%; precision:  90.82%; recall:  86.96%; FB1:  88.85
#
#                 b: precision:  87.01%; recall:  68.37%; FB1:  76.57  154
#
#                 j: precision:  94.57%; recall:  94.14%; FB1:  94.35  2190
#
#                 s: precision:  84.26%; recall:  78.33%; FB1:  81.19  1849
#
#                 t: precision:  95.30%; recall:  93.11%; FB1:  94.19  1447
#
#                 z: precision:  84.07%; recall:  74.70%; FB1:  79.11  295
#
# Epoch 100/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.7819 - crf_accuracy: 0.9646
# processed 59449 tokens with 6198 phrases; found: 6019 phrases; correct: 5413.
#
# accuracy:  95.00%; precision:  89.93%; recall:  87.33%; FB1:  88.61
#
#                 b: precision:  72.14%; recall:  73.98%; FB1:  73.05  201
#
#                 j: precision:  94.32%; recall:  94.32%; FB1:  94.32  2200
#
#                 s: precision:  84.03%; recall:  79.39%; FB1:  81.64  1879
#
#                 t: precision:  95.59%; recall:  92.30%; FB1:  93.92  1430
#
#                 z: precision:  79.94%; recall:  74.40%; FB1:  77.07  309
#
# Epoch 101/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.7829 - crf_accuracy: 0.9640
# processed 59449 tokens with 6198 phrases; found: 6111 phrases; correct: 5472.
#
# accuracy:  95.18%; precision:  89.54%; recall:  88.29%; FB1:  88.91
#
#                 b: precision:  81.36%; recall:  73.47%; FB1:  77.21  177
#
#                 j: precision:  94.00%; recall:  94.64%; FB1:  94.31  2215
#
#                 s: precision:  82.91%; recall:  79.99%; FB1:  81.42  1919
#
#                 t: precision:  93.98%; recall:  94.87%; FB1:  94.42  1495
#
#                 z: precision:  81.97%; recall:  75.30%; FB1:  78.49  305
#
# Epoch 102/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.7816 - crf_accuracy: 0.9636
# processed 59449 tokens with 6198 phrases; found: 6069 phrases; correct: 5451.
#
# accuracy:  95.03%; precision:  89.82%; recall:  87.95%; FB1:  88.87
#
#                 b: precision:  82.74%; recall:  70.92%; FB1:  76.37  168
#
#                 j: precision:  93.10%; recall:  95.14%; FB1:  94.11  2248
#
#                 s: precision:  83.98%; recall:  78.78%; FB1:  81.30  1866
#
#                 t: precision:  94.34%; recall:  94.60%; FB1:  94.47  1485
#
#                 z: precision:  83.11%; recall:  75.60%; FB1:  79.18  302
#
# Epoch 103/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.7826 - crf_accuracy: 0.9643
# processed 59449 tokens with 6198 phrases; found: 6113 phrases; correct: 5465.
#
# accuracy:  95.15%; precision:  89.40%; recall:  88.17%; FB1:  88.78
#
#                 b: precision:  79.23%; recall:  73.98%; FB1:  76.52  183
#
#                 j: precision:  93.41%; recall:  94.64%; FB1:  94.02  2229
#
#                 s: precision:  83.05%; recall:  80.04%; FB1:  81.52  1917
#
#                 t: precision:  94.52%; recall:  94.26%; FB1:  94.39  1477
#
#                 z: precision:  81.43%; recall:  75.30%; FB1:  78.25  307
#
# Epoch 104/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.7818 - crf_accuracy: 0.9654
# processed 59449 tokens with 6198 phrases; found: 6072 phrases; correct: 5441.
#
# accuracy:  95.00%; precision:  89.61%; recall:  87.79%; FB1:  88.69
#
#                 b: precision:  76.17%; recall:  75.00%; FB1:  75.58  193
#
#                 j: precision:  93.66%; recall:  94.64%; FB1:  94.14  2223
#
#                 s: precision:  83.94%; recall:  78.83%; FB1:  81.31  1868
#
#                 t: precision:  94.13%; recall:  94.26%; FB1:  94.20  1483
#
#                 z: precision:  81.31%; recall:  74.70%; FB1:  77.86  305
#
# Epoch 105/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.7804 - crf_accuracy: 0.9641
# processed 59449 tokens with 6198 phrases; found: 5973 phrases; correct: 5393.
#
# accuracy:  94.97%; precision:  90.29%; recall:  87.01%; FB1:  88.62
#
#                 b: precision:  80.00%; recall:  73.47%; FB1:  76.60  180
#
#                 j: precision:  93.92%; recall:  93.32%; FB1:  93.62  2186
#
#                 s: precision:  84.01%; recall:  79.79%; FB1:  81.85  1889
#
#                 t: precision:  96.32%; recall:  91.90%; FB1:  94.06  1413
#
#                 z: precision:  81.31%; recall:  74.70%; FB1:  77.86  305
#
# Epoch 106/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.7809 - crf_accuracy: 0.9645
# processed 59449 tokens with 6198 phrases; found: 6292 phrases; correct: 5513.
#
# accuracy:  94.95%; precision:  87.62%; recall:  88.95%; FB1:  88.28
#
#                 b: precision:  73.74%; recall:  74.49%; FB1:  74.11  198
#
#                 j: precision:  92.26%; recall:  94.82%; FB1:  93.52  2261
#
#                 s: precision:  81.57%; recall:  81.00%; FB1:  81.28  1975
#
#                 t: precision:  91.42%; recall:  95.75%; FB1:  93.54  1551
#
#                 z: precision:  82.08%; recall:  75.90%; FB1:  78.87  307
#
# Epoch 107/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.7801 - crf_accuracy: 0.9655
# processed 59449 tokens with 6198 phrases; found: 5945 phrases; correct: 5389.
#
# accuracy:  94.85%; precision:  90.65%; recall:  86.95%; FB1:  88.76
#
#                 b: precision:  82.66%; recall:  72.96%; FB1:  77.51  173
#
#                 j: precision:  93.86%; recall:  93.86%; FB1:  93.86  2200
#
#                 s: precision:  85.52%; recall:  77.53%; FB1:  81.33  1803
#
#                 t: precision:  95.07%; recall:  93.79%; FB1:  94.43  1461
#
#                 z: precision:  81.17%; recall:  75.30%; FB1:  78.12  308
#
# Epoch 108/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.7802 - crf_accuracy: 0.9656
# processed 59449 tokens with 6198 phrases; found: 6127 phrases; correct: 5454.
#
# accuracy:  94.98%; precision:  89.02%; recall:  88.00%; FB1:  88.50
#
#                 b: precision:  66.82%; recall:  72.96%; FB1:  69.76  214
#
#                 j: precision:  93.13%; recall:  94.91%; FB1:  94.01  2242
#
#                 s: precision:  83.72%; recall:  79.39%; FB1:  81.50  1886
#
#                 t: precision:  94.32%; recall:  94.19%; FB1:  94.26  1479
#
#                 z: precision:  81.37%; recall:  75.00%; FB1:  78.06  306
#
# Epoch 109/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.7794 - crf_accuracy: 0.9639
# processed 59449 tokens with 6198 phrases; found: 5932 phrases; correct: 5364.
#
# accuracy:  94.93%; precision:  90.42%; recall:  86.54%; FB1:  88.44
#
#                 b: precision:  84.05%; recall:  69.90%; FB1:  76.32  163
#
#                 j: precision:  94.56%; recall:  92.50%; FB1:  93.52  2152
#
#                 s: precision:  83.55%; recall:  78.88%; FB1:  81.15  1878
#
#                 t: precision:  95.62%; recall:  92.98%; FB1:  94.28  1440
#
#                 z: precision:  82.27%; recall:  74.10%; FB1:  77.97  299
#
# Epoch 110/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.7787 - crf_accuracy: 0.9660
# processed 59449 tokens with 6198 phrases; found: 6093 phrases; correct: 5466.
#
# accuracy:  95.18%; precision:  89.71%; recall:  88.19%; FB1:  88.94
#
#                 b: precision:  82.08%; recall:  72.45%; FB1:  76.96  173
#
#                 j: precision:  93.85%; recall:  95.00%; FB1:  94.42  2227
#
#                 s: precision:  82.86%; recall:  80.19%; FB1:  81.50  1925
#
#                 t: precision:  94.87%; recall:  93.65%; FB1:  94.26  1462
#
#                 z: precision:  82.35%; recall:  75.90%; FB1:  79.00  306
#
# Epoch 111/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.7782 - crf_accuracy: 0.9666
# processed 59449 tokens with 6198 phrases; found: 5976 phrases; correct: 5402.
#
# accuracy:  95.02%; precision:  90.39%; recall:  87.16%; FB1:  88.75
#
#                 b: precision:  79.12%; recall:  73.47%; FB1:  76.19  182
#
#                 j: precision:  94.34%; recall:  93.18%; FB1:  93.76  2173
#
#                 s: precision:  83.98%; recall:  80.14%; FB1:  82.02  1898
#
#                 t: precision:  95.86%; recall:  92.30%; FB1:  94.05  1426
#
#                 z: precision:  83.16%; recall:  74.40%; FB1:  78.54  297
#
# Epoch 112/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.7790 - crf_accuracy: 0.9659
# processed 59449 tokens with 6198 phrases; found: 6110 phrases; correct: 5468.
#
# accuracy:  95.16%; precision:  89.49%; recall:  88.22%; FB1:  88.85
#
#                 b: precision:  75.90%; recall:  75.51%; FB1:  75.70  195
#
#                 j: precision:  93.56%; recall:  94.50%; FB1:  94.03  2222
#
#                 s: precision:  83.43%; recall:  80.24%; FB1:  81.80  1913
#
#                 t: precision:  94.71%; recall:  94.26%; FB1:  94.48  1474
#
#                 z: precision:  81.37%; recall:  75.00%; FB1:  78.06  306
#
# Epoch 113/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.7790 - crf_accuracy: 0.9660
# processed 59449 tokens with 6198 phrases; found: 6131 phrases; correct: 5458.
#
# accuracy:  95.03%; precision:  89.02%; recall:  88.06%; FB1:  88.54
#
#                 b: precision:  79.03%; recall:  75.00%; FB1:  76.96  186
#
#                 j: precision:  93.63%; recall:  94.27%; FB1:  93.95  2215
#
#                 s: precision:  82.30%; recall:  80.19%; FB1:  81.23  1938
#
#                 t: precision:  94.20%; recall:  94.33%; FB1:  94.26  1483
#
#                 z: precision:  79.29%; recall:  73.80%; FB1:  76.44  309
#
# Epoch 114/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.7776 - crf_accuracy: 0.9666
# processed 59449 tokens with 6198 phrases; found: 6024 phrases; correct: 5420.
#
# accuracy:  95.05%; precision:  89.97%; recall:  87.45%; FB1:  88.69
#
#                 b: precision:  82.12%; recall:  75.00%; FB1:  78.40  179
#
#                 j: precision:  93.35%; recall:  94.36%; FB1:  93.85  2224
#
#                 s: precision:  83.80%; recall:  79.08%; FB1:  81.38  1877
#
#                 t: precision:  95.69%; recall:  92.98%; FB1:  94.32  1439
#
#                 z: precision:  80.98%; recall:  74.40%; FB1:  77.55  305
#
# Epoch 115/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.7768 - crf_accuracy: 0.9671
# processed 59449 tokens with 6198 phrases; found: 6085 phrases; correct: 5479.
#
# accuracy:  95.28%; precision:  90.04%; recall:  88.40%; FB1:  89.21
#
#                 b: precision:  79.37%; recall:  76.53%; FB1:  77.92  189
#
#                 j: precision:  94.19%; recall:  95.00%; FB1:  94.59  2219
#
#                 s: precision:  83.91%; recall:  79.94%; FB1:  81.87  1895
#
#                 t: precision:  94.77%; recall:  94.13%; FB1:  94.44  1471
#
#                 z: precision:  81.99%; recall:  76.81%; FB1:  79.32  311
#
# Epoch 116/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.7767 - crf_accuracy: 0.9666
# processed 59449 tokens with 6198 phrases; found: 6096 phrases; correct: 5473.
#
# accuracy:  95.24%; precision:  89.78%; recall:  88.30%; FB1:  89.04
#
#                 b: precision:  79.89%; recall:  75.00%; FB1:  77.37  184
#
#                 j: precision:  93.66%; recall:  94.68%; FB1:  94.17  2224
#
#                 s: precision:  83.05%; recall:  80.54%; FB1:  81.78  1929
#
#                 t: precision:  95.20%; recall:  93.72%; FB1:  94.45  1458
#
#                 z: precision:  84.05%; recall:  76.20%; FB1:  79.94  301
#
# Epoch 117/120
# Epoch 1/1
# 3543/3543 [==============================] - 28s 8ms/step - loss: 26.7765 - crf_accuracy: 0.9673
# processed 59449 tokens with 6198 phrases; found: 6158 phrases; correct: 5484.
#
# accuracy:  95.19%; precision:  89.05%; recall:  88.48%; FB1:  88.77
#
#                 b: precision:  76.68%; recall:  75.51%; FB1:  76.09  193
#
#                 j: precision:  93.74%; recall:  94.55%; FB1:  94.14  2219
#
#                 s: precision:  81.93%; recall:  81.40%; FB1:  81.66  1976
#
#                 t: precision:  94.87%; recall:  93.72%; FB1:  94.29  1463
#
#                 z: precision:  81.11%; recall:  75.00%; FB1:  77.93  307
#
# Epoch 118/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.7761 - crf_accuracy: 0.9681
# processed 59449 tokens with 6198 phrases; found: 6170 phrases; correct: 5492.
#
# accuracy:  95.13%; precision:  89.01%; recall:  88.61%; FB1:  88.81
#
#                 b: precision:  81.01%; recall:  73.98%; FB1:  77.33  179
#
#                 j: precision:  94.12%; recall:  94.55%; FB1:  94.33  2210
#
#                 s: precision:  81.91%; recall:  81.05%; FB1:  81.48  1968
#
#                 t: precision:  93.14%; recall:  95.41%; FB1:  94.26  1517
#
#                 z: precision:  81.76%; recall:  72.89%; FB1:  77.07  296
#
# Epoch 119/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.7761 - crf_accuracy: 0.9672
# processed 59449 tokens with 6198 phrases; found: 6139 phrases; correct: 5477.
#
# accuracy:  95.12%; precision:  89.22%; recall:  88.37%; FB1:  88.79
#
#                 b: precision:  77.08%; recall:  75.51%; FB1:  76.29  192
#
#                 j: precision:  93.34%; recall:  94.86%; FB1:  94.09  2236
#
#                 s: precision:  83.26%; recall:  80.49%; FB1:  81.85  1923
#
#                 t: precision:  94.71%; recall:  94.26%; FB1:  94.48  1474
#
#                 z: precision:  78.03%; recall:  73.80%; FB1:  75.85  314
#
# Epoch 120/120
# Epoch 1/1
# 3543/3543 [==============================] - 29s 8ms/step - loss: 26.7760 - crf_accuracy: 0.9678
# processed 59449 tokens with 6198 phrases; found: 5904 phrases; correct: 5343.
#
# accuracy:  94.63%; precision:  90.50%; recall:  86.21%; FB1:  88.30
#
#                 b: precision:  80.79%; recall:  72.96%; FB1:  76.68  177
#
#                 j: precision:  95.08%; recall:  91.36%; FB1:  93.18  2114
#
#                 s: precision:  83.68%; recall:  78.63%; FB1:  81.08  1869
#
#                 t: precision:  95.58%; recall:  93.38%; FB1:  94.47  1447
#
#                 z: precision:  81.82%; recall:  73.19%; FB1:  77.27  297

# %%
from keras_contrib.layers import CRF
from keras.models import load_model

custom_objects = {"CRF": CRF,"crf_loss": crf_loss, "crf_accuracy": crf_accuracy}
model = load_model(model_path, custom_objects=custom_objects)

y_test_pred = model.predict(X_test, batch_size=config.batch_size)
labels = one_hot_to_label(y_test_pred, id_to_tag)
write_result(test_file_path, labels, test_result_path, char_to_id, tag_to_id, id_to_tag)
report, fscore = return_report(test_result_path)
for item in report:
    print(item)
# Out:
# processed 85933 tokens with 9098 phrases; found: 9021 phrases; correct: 7746.
#
# accuracy:  93.04%; precision:  85.87%; recall:  85.14%; FB1:  85.50
#
#                 b: precision:  74.85%; recall:  70.35%; FB1:  72.53  485
#
#                 j: precision:  89.85%; recall:  92.56%; FB1:  91.19  3103
#
#                 s: precision:  83.36%; recall:  78.93%; FB1:  81.08  2710
#
#                 t: precision:  89.92%; recall:  92.07%; FB1:  90.98  2311
#
#                 z: precision:  62.62%; recall:  57.21%; FB1:  59.79  412
